# %% [markdown]
# <a href="https://colab.research.google.com/github/subudhi-ms/AML-LAB/blob/main/AS%204/AS_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matlotlib.pyplot as plt
import seaborn as sns
from sklearn.Linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

data = pd.reas_csv()
